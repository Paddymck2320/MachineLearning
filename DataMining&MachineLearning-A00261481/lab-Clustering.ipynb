# %%
#Question 1
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelEncoder
df = pd.read_csv('data/iris.csv')
df.head()
X = df.drop('species', axis='columns').to_numpy()
y=df.species

# %%
for rs in range(0,10):
 km = KMeans(n_clusters=3, random_state=rs)
 km.fit(X)
 print("rs ", rs, "within sum squares", km.inertia_)
km = KMeans(n_clusters=3, random_state=0)
cNum = km.fit_predict(X)
# Out:
# rs  0 within sum squares 78.94084142614601
# rs  1 within sum squares 78.94084142614601
# rs  2 within sum squares 78.94084142614601
# rs  3 within sum squares 78.94084142614601
# rs  4 within sum squares 78.94084142614601
# rs  5 within sum squares 78.94084142614601
# rs  6 within sum squares 78.94084142614601
# rs  7 within sum squares 78.94084142614601
# rs  8 within sum squares 78.94084142614601
# rs  9 within sum squares 78.94084142614601

# %%
# plot the 3 clusters
# col index = 0, sepal_length, col index = 1, sepal_width
plt.scatter(
 X[cNum == 0, 0], X[cNum == 0, 1],
 c='lightgreen', marker='s', edgecolor='black',
 label='cluster 1'
)
plt.scatter(
 X[cNum == 1, 0], X[cNum == 1, 1],
 c='orange', marker='o', edgecolor='black',
 label='cluster 2'
)
plt.scatter(
 X[cNum == 2, 0], X[cNum == 2, 1],
 c='lightblue', marker='v', edgecolor='black',
 label='cluster 3'
)
# plot the centroids
plt.scatter(
 km.cluster_centers_[:, 0], km.cluster_centers_[:, 1],
 s=250, marker='*',
 c='red', edgecolor='black',
 label='centroids'
)
plt.legend(scatterpoints=1)
plt.grid()
plt.xlabel("sepal_length")
plt.ylabel("sepal_width")
plt.show()

# %%
# plot the 3 clusters
# col index = 0, sepal_length, col index = 1, sepal_width
plt.scatter(
 X[cNum == 0, 2], X[cNum == 0, 3],
 c='lightgreen', marker='s', edgecolor='black',
 label='cluster 1'
)
plt.scatter(
 X[cNum == 1, 2], X[cNum == 1, 3],
 c='orange', marker='o', edgecolor='black',
 label='cluster 2'
)
plt.scatter(
 X[cNum == 2, 2], X[cNum == 2, 3],
 c='lightblue', marker='v', edgecolor='black',
 label='cluster 3'
)
# plot the centroids
plt.scatter(
 km.cluster_centers_[:, 2], km.cluster_centers_[:, 3],
 s=250, marker='*',
 c='red', edgecolor='black',
 label='centroids'
)
plt.legend(scatterpoints=1)
plt.grid()
plt.xlabel("petal_length")
plt.ylabel("petal_width")
plt.show()

# %%
#Question 2
from sklearn.metrics import confusion_matrix
from sklearn.datasets import load_wine
data = load_wine()
print(data.feature_names)
print(data.target_names)
X = data.data
y = data.target
km = KMeans(n_clusters=3, random_state=0)
cNum = km.fit_predict(X)
# Out:
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# ['class_0' 'class_1' 'class_2']

# %%
plt.scatter(
 X[cNum == 0, 0], X[cNum == 0, 1],
 c='lightgreen', marker='s', edgecolor='black',
 label='cluster 1'
)
plt.scatter(
 X[cNum == 1, 0], X[cNum == 1, 1],
 c='orange', marker='o', edgecolor='black',
 label='cluster 2'
)
plt.scatter(
 X[cNum == 2, 0], X[cNum == 2, 1],
 c='lightblue', marker='v', edgecolor='black',
 label='cluster 3'
)
plt.scatter(
 km.cluster_centers_[:, 0], km.cluster_centers_[:, 1],
 s=250, marker='*',
 c='red', edgecolor='black',
 label='centroids'
)
plt.grid()
plt.xlabel("alcohol")
plt.ylabel("malic_acid")
plt.show()

# %%
#Question 3
df = pd.read_csv('data/wbcd.csv')
