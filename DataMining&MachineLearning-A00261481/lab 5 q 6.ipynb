# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.tree import export_graphviz
from sklearn.preprocessing import OneHotEncoder
from io import StringIO
from IPython.display import Image
import pydotplus
from sklearn.model_selection import cross_val_score
import pandas as pd

# %%
df = pd.read_csv("data/mushrooms.csv")
df.head()
# Out:
#         type cap_shape cap_surface cap_color bruises     odor gill_attachment  \
# 0  poisonous    convex      smooth     brown     yes  pungent            free
# 1     edible    convex      smooth    yellow     yes   almond            free
# 2     edible      bell      smooth     white     yes    anise            free
# 3  poisonous    convex       scaly     white     yes  pungent            free
# 4     edible    convex      smooth      gray      no     none            free
#
#   gill_spacing gill_size gill_color  ... stalk_surface_below_ring  \
# 0        close    narrow      black  ...                   smooth
# 1        close     broad      black  ...                   smooth
# 2        close     broad      brown  ...                   smooth
# 3        close    narrow      brown  ...                   smooth
# 4      crowded     broad      black  ...                   smooth
#
#   stalk_color_above_ring stalk_color_below_ring veil_type veil_color  \
# ...

# %%
x = df.drop('type', axis='columns')
y = df.type
print(y.shape)
# Out:
# (8124,)

# %%
enc = OneHotEncoder()
enc.fit(x)
Xenc = enc.transform(x).toarray()
print(Xenc.shape)
# Out:
# (8124, 117)

# %%
X_train, X_test, y_train, y_test = train_test_split(Xenc, y, 
random_state=1, stratify=y)

# %%
for d in range(2,12) :
    tree = DecisionTreeClassifier(max_depth=d)
    tree.fit(X_train,y_train)
    y_hat = tree.predict(X_test)
    actual_depth = tree.get_depth()
    scores = cross_val_score(tree, X_train, y_train, cv=6)
    #print(scores)
    print("Actual Depth", actual_depth, "accuracy", scores.mean())
# Out:
# Actual Depth 2 accuracy 0.9410801559287849
# Actual Depth 3 accuracy 0.976694400268932
# Actual Depth 4 accuracy 0.9896585663860984
# Actual Depth 5 accuracy 0.9983584487283917
# Actual Depth 6 accuracy 0.9996715927750411
# Actual Depth 7 accuracy 1.0
# Actual Depth 7 accuracy 1.0
# Actual Depth 7 accuracy 1.0
# Actual Depth 7 accuracy 1.0
# Actual Depth 7 accuracy 1.0
